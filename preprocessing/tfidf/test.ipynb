# %%
import numpy as np
import pandas as pd
import re
from typing import List

# %%
class TFIDF:
    def __init__(self):
        # Từ điển lưu trữ IDF
        self.idf_dict = {}
        # Từ vựng
        self.vocabulary = []
    
    def remove_tags(self, text: str) -> np.ndarray:
        """
        Tiền xử lý văn bản
        
        Parameters:
        text (str): Văn bản đầu vào
        
        Returns:
        numpy.ndarray: Mảng các từ đã xử lý
        """
        result = re.sub(r'<.*?>','',text)           #xoá HTML tags, tiền tố r nghĩa là raw
        result = re.sub('https://.*','',result)     #xoá URLs
        result = re.sub(r'[^\w\s]', '',result)      #xoá non-alphanumeric characters ví dụ như các dấu câu
        result = result.lower()                     # Chuyển về chữ thường
        
        # Tách từ và chuyển thành numpy array
        return np.array(result.split())
    
    def fit(self, documents: List[str]) -> 'TFIDF':
        """
        Học từ vựng và tính IDF
        
        Parameters:
        documents (List[str]): Danh sách các văn bản
        
        Returns:
        self: Đối tượng hiện tại
        """
        # Xử lý văn bản thành numpy arrays
        processed_docs = [self.remove_tags(doc) for doc in documents]
        
        # Chuyển sang DataFrame để dễ xử lý
        df_docs = pd.DataFrame({'words': processed_docs})
        
        # Tổng số văn bản
        total_docs = len(documents)
        
        # Đếm số văn bản chứa từng từ
        word_doc_count = {}
        for doc_words in processed_docs:
            unique_words = set(doc_words)  # Chỉ đếm mỗi từ một lần trong một văn bản
            for word in unique_words:
                word_doc_count[word] = word_doc_count.get(word, 0) + 1
        
        # Tính IDF sử dụng numpy
        self.idf_dict = {
            word: np.log(total_docs / (count)) + 1 
            for word, count in word_doc_count.items()
        }
        
        # Lưu từ vựng
        self.vocabulary = list(word_doc_count.keys())
        
        return self
    
    def transform(self, documents: List[str]) -> np.ndarray:
        """
        Chuyển đổi văn bản thành ma trận TF-IDF
        
        Parameters:
        documents (List[str]): Danh sách các văn bản
        
        Returns:
        numpy.ndarray: Ma trận TF-IDF
        """
        # Khởi tạo ma trận kết quả
        tfidf_matrix = np.zeros((len(documents), len(self.vocabulary)))
        
        # Xử lý từng văn bản
        for i, doc in enumerate(documents):
            # Tiền xử lý văn bản
            words = self.remove_tags(doc)
            
            # Tính Term Frequency (TF) sử dụng pandas
            word_counts = pd.Series(words).value_counts()
            total_words = len(words)
            
            # Tạo vector cho văn bản
            for j, vocab_word in enumerate(self.vocabulary):
                # Tính TF
                tf = word_counts.get(vocab_word, 0) / total_words
                
                # Tính TF-IDF
                idf = self.idf_dict.get(vocab_word, 0)
                tfidf_matrix[i, j] = tf * idf
        
        return tfidf_matrix

# %%
    df = pd.read_csv('C:/Users/ADMIN/Movie/IMDB Dataset.csv')
    df.head()['review']
# Out:
# 0    One of the other reviewers has mentioned that ...
# 1    A wonderful little production. <br /><br />The...
# 2    I thought this was a wonderful way to spend ti...
# 3    Basically there's a family where a little boy ...
# 4    Petter Mattei's "Love in the Time of Money" is...
# Name: review, dtype: object

# %%
def main():
    df = pd.read_csv('C:/Users/ADMIN/Movie/IMDB Dataset.csv')
    dfs=df.head()
    reviews = dfs['review'].values
    reviews = reviews.tolist()
    reviews
    vectorizer = TFIDF()
    # Học từ vựng và IDF
    vectorizer.fit(reviews)
    
    # # In ra từ vựng
    # print("Từ vựng:")
    # print(vectorizer.vocabulary)

    # In ra IDF của các từ
    print("\nIDF của các từ:")
    for word, idf in vectorizer.idf_dict.items():
        print(f"{word}: {idf:.4f}")

    # Chuyển đổi văn bản thành ma trận TF-IDF
    tfidf_matrix = vectorizer.transform(reviews)
    
    # Tạo DataFrame để hiển thị kết quả
    tfidf_df = pd.DataFrame(
        tfidf_matrix, 
        columns=vectorizer.vocabulary
    )
    
    print("\nMa trận TF-IDF:")
    print(tfidf_df)

# %%
if __name__ == "__main__":
    main()
# Out:
# IDF của các từ:
# one: 1.2231
# high: 2.6094
# oswald: 2.6094
# privacy: 2.6094
# security: 2.6094
# gangstas: 2.6094
# in: 1.2231
# focuses: 2.6094
# muslims: 2.6094
# guards: 2.6094
# on: 1.2231
# 1: 2.6094
# happened: 2.6094
# a: 1.0000
# i: 1.5108
# if: 1.9163
# doesnt: 2.6094
# appeal: 2.6094
# drugs: 2.6094
# where: 1.5108
# inwards: 2.6094
# uncomfortable: 2.6094
# wholl: 2.6094
# irish: 2.6094
# watched: 1.9163
# to: 1.0000
# touch: 2.6094
# darker: 2.6094
# use: 1.9163
# would: 2.6094
# out: 1.5108
# oz: 2.6094
# word: 2.6094
# be: 1.5108
# graphic: 2.6094
# called: 2.6094
# experimental: 2.6094
# fronts: 2.6094
# show: 2.6094
# em: 2.6094
# set: 2.6094
# bitches: 2.6094
# viewingthats: 2.6094
# of: 1.0000
# home: 1.9163
# glass: 2.6094
# city: 1.9163
# shows: 2.6094
# ever: 2.6094
# accustomed: 2.6094
# hearted: 2.6094
# no: 1.9163
# section: 2.6094
# this: 1.5108
# your: 2.6094
# away: 2.6094
# and: 1.0000
# goes: 2.6094
# nickname: 2.6094
# scuffles: 2.6094
# after: 2.6094
# mainstream: 2.6094
# developed: 2.6094
# around: 2.6094
# was: 1.9163
# state: 2.6094
# order: 2.6094
# charm: 2.6094
# me: 2.6094
# pulls: 2.6094
# penitentary: 2.6094
# got: 1.9163
# mainly: 2.6094
# fact: 2.6094
# mentioned: 2.6094
# episode: 2.6094
# that: 1.5108
# brutality: 2.6094
# emerald: 2.6094
# timid: 2.6094
# into: 1.9163
# violence: 2.6094
# wordit: 2.6094
# ready: 2.6094
# christians: 2.6094
# painted: 2.6094
# inmates: 2.6094
# well: 1.2231
# agreements: 2.6094
# side: 2.6094
# thing: 1.9163
# you: 1.5108
# never: 1.9163
# an: 2.6094
# classic: 2.6094
# sold: 2.6094
# forget: 2.6094
# struck: 2.6094
# street: 2.6094
# unflinching: 2.6094
# may: 1.9163
# punches: 2.6094
# audiences: 2.6094
# get: 2.6094
# being: 1.9163
# more: 1.9163
# right: 1.9163
# wouldnt: 2.6094
# not: 1.2231
# pretty: 2.6094
# first: 1.9163
# surreal: 2.6094
# become: 1.9163
# comfortable: 2.6094
# levels: 2.6094
# their: 1.5108
# nasty: 2.6094
# mess: 2.6094
# saw: 2.6094
# far: 2.6094
# due: 2.6094
# but: 1.2231
# all: 1.2231
# with: 1.0000
# moreso: 2.6094
# turned: 2.6094
# manyaryans: 2.6094
# faint: 2.6094
# face: 2.6094
# youll: 2.6094
# watching: 1.5108
# or: 1.5108
# what: 1.9163
# is: 1.0000
# just: 1.9163
# experience: 2.6094
# dealings: 2.6094
# the: 1.0000
# they: 1.5108
# nickel: 2.6094
# stares: 2.6094
# kill: 1.9163
# agenda: 2.6094
# dare: 1.9163
# couldnt: 2.6094
# latinos: 2.6094
# from: 2.6094
# taste: 2.6094
# dodgy: 2.6094
# awayi: 2.6094
# pictures: 2.6094
# reviewers: 2.6094
# are: 1.0000
# methe: 2.6094
# it: 1.5108
# shady: 2.6094
# as: 1.5108
# for: 1.5108
# so: 2.6094
# injustice: 2.6094
# regards: 2.6094
# cells: 2.6094
# main: 2.6094
# crooked: 2.6094
# given: 2.6094
# middle: 2.6094
# scenes: 1.9163
# italians: 2.6094
# mannered: 2.6094
# romanceoz: 2.6094
# its: 1.9163
# go: 1.9163
# can: 1.9163
# lack: 2.6094
# hardcore: 2.6094
# hooked: 2.6094
# maximum: 2.6094
# have: 1.5108
# exactly: 1.9163
# class: 2.6094
# trust: 2.6094
# skills: 2.6094
# prison: 2.6094
# which: 1.2231
# death: 2.6094
# other: 2.6094
# about: 1.5108
# sex: 2.6094
# has: 1.5108
# say: 1.9163
# things: 2.6094
# dream: 2.6094
# sense: 2.6094
# entire: 2.6094
# technique: 2.6094
# guided: 2.6094
# unassuming: 2.6094
# sheen: 2.6094
# wonderful: 1.9163
# production: 2.6094
# sometimes: 2.6094
# halliwell: 2.6094
# too: 1.9163
# references: 2.6094
# remains: 2.6094
# terribly: 2.6094
# rather: 2.6094
# polari: 2.6094
# piece: 2.6094
# senses: 2.6094
# plays: 2.6094
# halliwells: 2.6094
# very: 2.6094
# guard: 2.6094
# particularly: 2.6094
# down: 1.9163
# our: 2.6094
# traditional: 2.6094
# performed: 2.6094
# comes: 2.6094
# worth: 2.6094
# filming: 2.6094
# see: 1.2231
# he: 2.6094
# decorating: 2.6094
# great: 1.9163
# by: 2.6094
# michael: 1.9163
# pat: 2.6094
# terrificly: 2.6094
# his: 1.2231
# entries: 2.6094
# gives: 2.6094
# comedy: 1.9163
# life: 1.9163
# surface: 2.6094
# written: 2.6094
# diary: 2.6094
# only: 1.9163
# fantasy: 2.6094
# oldtimebbc: 2.6094
# really: 2.6094
# techniques: 2.6094
# sets: 2.6094
# williams: 2.6094
# extremely: 2.6094
# concerning: 2.6094
# seamless: 2.6094
# little: 1.9163
# knowledge: 2.6094
# masters: 2.6094
# disappears: 2.6094
# done: 2.6094
# flat: 2.6094
# truly: 2.6094
# actors: 2.6094
# discomforting: 2.6094
# orton: 2.6094
# chosen: 2.6094
# realism: 2.6094
# than: 1.5108
# editing: 2.6094
# solid: 2.6094
# murals: 2.6094
# then: 1.9163
# voices: 2.6094
# comforting: 2.6094
# every: 2.6094
# masterful: 2.6094
# fashion: 2.6094
# way: 1.9163
# air: 2.6094
# womanthis: 2.6094
# time: 1.9163
# johanson: 2.6094
# laughed: 2.6094
# grown: 2.6094
# her: 2.6094
# summer: 2.6094
# match: 2.6094
# lovethis: 2.6094
# comedies: 2.6094
# dialogue: 2.6094
# some: 1.9163
# plot: 2.6094
# realize: 2.6094
# tone: 2.6094
# killer: 2.6094
# young: 2.6094
# addiction: 2.6094
# managed: 2.6094
# simplistic: 2.6094
# allen: 2.6094
# bread: 2.6094
# spirited: 2.6094
# jewel: 2.6094
# likable: 2.6094
# been: 2.6094
# id: 2.6094
# while: 2.6094
# hot: 2.6094
# risk: 2.6094
# style: 2.6094
# most: 1.9163
# ive: 2.6094
# theater: 2.6094
# decade: 2.6094
# woodys: 2.6094
# wittier: 2.6094
# superman: 2.6094
# crown: 2.6094
# thought: 2.6094
# she: 2.6094
# conditioned: 2.6094
# image: 2.6094
# friends: 2.6094
# sitting: 2.6094
# average: 2.6094
# proof: 2.6094
# characters: 1.9163
# serial: 2.6094
# spend: 2.6094
# witty: 2.6094
# interesting: 2.6094
# prada: 2.6094
# years: 2.6094
# jumped: 2.6094
# devil: 2.6094
# even: 2.6094
# weekend: 2.6094
# impressed: 2.6094
# when: 1.9163
# 2: 2.6094
# at: 2.6094
# fully: 2.6094
# scarlet: 2.6094
# suspected: 2.6094
# sexy: 2.6094
# wears: 2.6094
# us: 1.9163
# lighthearted: 2.6094
# disappointed: 2.6094
# still: 2.6094
# woody: 2.6094
# point: 1.9163
# control: 2.6094
# career: 2.6094
# many: 2.6094
# drama: 2.6094
# arguing: 2.6094
# jake: 2.6094
# decide: 2.6094
# expected: 2.6094
# make: 1.9163
# decides: 2.6094
# descent: 2.6094
# meaningless: 2.6094
# 10: 2.6094
# dialogs: 2.6094
# instead: 2.6094
# family: 2.6094
# slower: 2.6094
# rambo: 2.6094
# boy: 2.6094
# them: 2.6094
# zombieok: 2.6094
# totally: 2.6094
# like: 2.6094
# going: 2.6094
# spots3: 2.6094
# watchable: 2.6094
# closet: 2.6094
# suddenly: 2.6094
# opera: 2.6094
# fighting: 2.6094
# timethis: 2.6094
# ruins: 2.6094
# must: 2.6094
# we: 1.9163
# shots: 2.6094
# theres: 2.6094
# thinks: 2.6094
# similar: 2.6094
# playing: 2.6094
# parents: 2.6094
# real: 2.6094
# youre: 2.6094
# movie: 1.9163
# soap: 2.6094
# zombie: 2.6094
# thriller: 2.6094
# basically: 2.6094
# ignore: 2.6094
# film: 1.9163
# boogeyman: 2.6094
# divorcing: 2.6094
# schnitzlers: 2.6094
# dawson: 2.6094
# luxurious: 2.6094
# situations: 2.6094
# good: 2.6094
# habitatthe: 2.6094
# steve: 2.6094
# power: 2.6094
# petter: 2.6094
# seems: 2.6094
# stages: 2.6094
# portrait: 2.6094
# await: 2.6094
# watch: 2.6094
# know: 2.6094
# carol: 2.6094
# fulfillment: 2.6094
# different: 2.6094
# telling: 2.6094
# love: 2.6094
# each: 2.6094
# wish: 2.6094
# look: 2.6094
# big: 2.6094
# talented: 2.6094
# director: 2.6094
# how: 2.6094
# inhabits: 2.6094
# picture: 2.6094
# previous: 2.6094
# case: 2.6094
# place: 2.6094
# these: 2.6094
# another: 2.6094
# sincere: 2.6094
# mattei: 2.6094
# transfers: 2.6094
# discerns: 2.6094
# same: 2.6094
# rest: 2.6094
# next: 2.6094
# matteis: 2.6094
# kane: 2.6094
# sophisticated: 2.6094
# direction: 2.6094
# do: 2.6094
# own: 2.6094
# anxiously: 2.6094
# world: 2.6094
# human: 2.6094
# best: 2.6094
# success: 2.6094
# relations: 2.6094
# theme: 2.6094
# cast: 2.6094
# encounter: 2.6094
# connect: 2.6094
# offers: 2.6094
# luck: 2.6094
# present: 2.6094
# visually: 2.6094
# souls: 2.6094
# contact: 2.6094
# money: 2.6094
# buscemi: 2.6094
# meet: 2.6094
# person: 2.6094
# arthur: 2.6094
# play: 2.6094
# live: 2.6094
# stunning: 2.6094
# imperioli: 2.6094
# york: 2.6094
# people: 2.6094
# adrian: 2.6094
# connected: 2.6094
# under: 2.6094
# new: 2.6094
# variation: 2.6094
# vivid: 2.6094
# gets: 2.6094
# action: 2.6094
# come: 2.6094
# find: 2.6094
# mr: 2.6094
# work: 2.6094
# encounterthe: 2.6094
# rosario: 2.6094
# grenier: 2.6094
# loneliness: 2.6094
# stylishly: 2.6094
# alivewe: 2.6094
# taken: 2.6094
# acting: 2.6094
#
# Ma trận TF-IDF:
#         one      high    oswald   privacy  security  gangstas        in  \
# 0  0.004064  0.017338  0.008669  0.008669  0.008669  0.008669  0.012191
# 1  0.007841  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.007550  0.000000  0.000000  0.000000  0.000000  0.000000  0.030201
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.018963
# 4  0.033058  0.000000  0.000000  0.000000  0.000000  0.000000  0.033058
#
#     focuses   muslims    guards  ...        mr      work  encounterthe  \
# 0  0.008669  0.008669  0.008669  ...  0.000000  0.000000      0.000000
# 1  0.000000  0.000000  0.000000  ...  0.000000  0.000000      0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000      0.000000
# 3  0.000000  0.000000  0.000000  ...  0.000000  0.000000      0.000000
# 4  0.000000  0.000000  0.000000  ...  0.035263  0.011754      0.011754
#
#     rosario   grenier  loneliness  stylishly   alivewe     taken    acting
# 0  0.000000  0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 4  0.011754  0.011754    0.011754   0.011754  0.011754  0.011754  0.011754
#
# [5 rows x 490 columns]
